# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_file = r"C:\Users\microspheres\Desktop\20231016_over_weeknd_no_plastic.txt"
data = np.genfromtxt(data_file, delimiter=',', skip_header=34).T

# %%
tt = data[0] / 3600
plt.plot(tt, data[1], label='H2')
plt.plot(tt, data[5], label='H2O')

plt.xlabel('Time (hour)')
plt.ylabel('Pressure (Torr)')
plt.yscale('log')
plt.legend(frameon=False)
