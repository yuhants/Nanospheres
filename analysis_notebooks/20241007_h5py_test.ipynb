# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
file_name = r"D:\h5test_0.hdf5"
f = h5py.File(file_name, 'r')
delta_t = f['channel_d'].attrs['delta_t']
dd = f['channel_d'][:]
ee = f['channel_e'][:]

# %%
f1 = h5py.File(r"D:\h5test_1.hdf5", 'r')
dd1 = f1['channel_d'][:]

tt = np.arange(0, dd.size*delta_t, delta_t)

# %%
plt.plot(tt, dd1)
