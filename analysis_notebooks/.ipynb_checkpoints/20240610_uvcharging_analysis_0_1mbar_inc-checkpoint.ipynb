# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import scipy.io as sio
import glob

from scipy.signal import butter, savgol_filter
from scipy.optimize import curve_fit
from scipy.interpolate import CubicSpline
from numpy.polynomial.polynomial import Polynomial

# %%
params = {'axes.titlesize': 18,
          'legend.fontsize': 14,
          'axes.labelsize': 18,
          'axes.titlesize': 18,
          'xtick.labelsize': 14,
          'ytick.labelsize': 14}
plt.rcParams.update(params)

# %%
def plot_charging(tt, aa, pp):
    fig, ax = plt.subplots(1, 1, figsize = (20, 4))
    ax_twin = ax.twinx()
    
    ax.plot(tt, aa, 'r.', markersize=12)
    ax_twin.plot(tt, pp, 'cyan')
    
    ax.set_ylabel('Demod amp (V)', fontsize=18)
    ax.set_xlabel('Time (s)', fontsize=18)
    ax_twin.set_ylabel('Phase amp (V)', fontsize=18)
    ax_twin.tick_params(axis='y', color='k')
    
    ax.spines['left'].set_color('red')
    ax.yaxis.label.set_color('red')
    ax.tick_params(axis='y', colors='red')
    
    ax_twin.spines['right'].set_color('blue')
    ax_twin.yaxis.label.set_color('blue')
    ax_twin.tick_params(axis='y', colors='blue')
    
    fig.tight_layout()
    plt.show()

# %%
def get_charge(aa, single_step=0.0125):
    """Apply a smoothing filter and round to the nearest integer"""
    raw_charge = aa/(-1 * single_step)
    return np.round(savgol_filter(raw_charge, 10, 1)).astype(int)

def plot_charging_calibrated(tt, aa, single_step=0.0125, ax=None):
    if ax is None:
        fig, ax = plt.subplots(1, 1, figsize = (20, 4))
    ax.plot(tt, aa/(-1*single_step), 'r.', markersize=12)

    # Force y-axis to use integers only
    ax.yaxis.get_major_locator().set_params(integer=True)
    ax.set_ylabel('Charge (-$e$)', fontsize=18)
    ax.set_xlabel('Time (s)', fontsize=18)
    ax.grid()

# %%
def load_charging_files(file_list):
    length = 0
    delta_t = 0
    amp, phase = [], []
    
    for file in file_list:
        data = sio.loadmat(file)
        length += data['Length'][0,0]
        delta_t = data['Tinterval'][0,0]
        amp.append(data['E'][:,0])
        phase.append(data['F'][:,0])
    
    tt = np.arange(length*delta_t, step=delta_t)
    aa = np.concatenate(amp)
    pp = np.concatenate(phase)

    return tt, aa, pp

# %% [markdown]
# ####  Determine charge

# %% [markdown]
# Use 0.0125 V as the single charge step. There are +- 1$e$ charge fluctuations, due to the oscillator frequency drift, so there is room to improve the analysis - e.g., there are a lot of step detection algorithms that exist https://en.wikipedia.org/wiki/Step_detection

# %%
data_dir = r"C:\Users\yuhan\Documents\Data\charging\20240515_uvcharging_dataset\nd_0_6"
prefix = '1100v_7_95Hz_3'
file_list = glob.glob(f"{data_dir}\{prefix}\*.mat")
tt, aa, pp = load_charging_files(file_list)

# %%
fig, ax = plt.subplots(1, 1, figsize = (8, 3))

raw_charge = aa/(-1 * 0.0125)
ax.plot(tt, raw_charge, 'r', alpha=0.5)

ax.set_xlabel('Time (s)', fontsize=14)
ax.set_ylabel('Charge (-$e$)', fontsize=14)
ax.grid()

charge = get_charge(aa, 0.0125)
ax.plot(tt, charge, 'r')

# %%
def get_step_idx(arr, tt):
    shifted_forward = np.roll(arr, 1)
    shifted_forward[:1] = arr[:1]
    nonzeros = np.nonzero(arr - shifted_forward)[0]
    
    good_idx = []
    pivot = nonzeros[0]
    for i, idx in enumerate(nonzeros):
        if len(good_idx) == 0:
            good_idx.append(idx)
        elif (tt[idx] - tt[pivot] > 1):
            good_idx.append(idx)
            pivot = idx
        else:
            pivot = idx
            continue
    return np.asarray(good_idx) - 1

# %%
step_idx = get_step_idx(charge, tt)
ax.plot(tt[step_idx], charge[step_idx], 'b.', markersize=10)

poly = Polynomial.fit(tt[step_idx], charge[step_idx], deg=2)
ax.plot(tt[step_idx], poly(tt[step_idx]), 'k--')

fig

# %%
print(f'Emission rate at 0 charge: {np.abs(poly.deriv(m=1)(poly.roots()[0]))} electrons/s' )
# Out:
# Emission rate at 0 charge: 0.07759176186979234 electrons/s

# %%
def get_emission_rate(tt, aa, single_step=0.0125):
    charge = get_charge(aa, single_step)
    step_idx = get_step_idx(charge, tt)
    poly = Polynomial.fit(tt[step_idx], charge[step_idx], deg=2)
    return np.abs(poly.deriv(m=1)(poly.roots()[0]))

# %%
# Collect all files into a list and plot
data_dir = r"C:\Users\yuhan\Documents\Data\charging\20240515_uvcharging_dataset\nofilter"
n_file_0 = 11

# The first data (number 0) has 70s dead time at the beginning - see description file
# so temporarily exclude that out
time, amp, phase = [], [], []
for i in range(1, n_file_0):
    prefix = '1100v_7_95Hz_' + str(i)
    file_list = glob.glob(f"{data_dir}\{prefix}\*.mat")
    tt, aa, pp = load_charging_files(file_list)
    
    time.append(tt)
    amp.append(aa)
    phase.append(pp)
    # plot_charging(tt, aa, pp)
    # plot_charging_calibrated(tt, aa, 0.0125, ax)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 4))
for i in range(n_file_0-1):
    ax.plot(time[i], amp[i]/(-1*0.0125), alpha=0.8)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Charge (-$e$)')
ax.set_ylim(-45, 10)
ax.set_xlim(0, 400)
ax.set_title('No Filter', fontsize=18)
# Out:
# Text(0.5, 1.0, 'No Filter')

# %%
data_dir = r"C:\Users\yuhan\Documents\Data\charging\20240515_uvcharging_dataset\nd_0_3"
n_file_03 = 6

time_03, amp_03, phase_03 = [], [], []
for i in range(n_file_03):
    prefix = '1100v_7_95Hz_' + str(i)
    file_list = glob.glob(f"{data_dir}\{prefix}\*.mat")
    tt, aa, pp = load_charging_files(file_list)
    
    # plot_charging(tt, aa, pp)
    # plot_charging_calibrated(tt, aa, 0.0125)
    time_03.append(tt)
    amp_03.append(aa)
    phase_03.append(pp)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 4))
for i in range(n_file_03):
    ax.plot(time_03[i], amp_03[i]/(-1*0.0125), alpha=0.8, label=str(i))

ax.set_xlabel('Time (s)')
ax.set_ylabel('Charge (-$e$)')
ax.set_ylim(-45, 10)
ax.set_xlim(0, 400)
ax.set_title('ND Filter: OD 0.3')
ax.legend()

# %%
data_dir = r"C:\Users\yuhan\Documents\Data\charging\20240515_uvcharging_dataset\nd_0_6"
n_file_06 = 5

time_06, amp_06, phase_06 = [], [], []
for i in range(n_file_06):
    prefix = '1100v_7_95Hz_' + str(i)
    file_list = glob.glob(f"{data_dir}\{prefix}\*.mat")
    tt, aa, pp = load_charging_files(file_list)
    
    # plot_charging(tt, aa, pp)
    # plot_charging_calibrated(tt, aa, 0.0125)
    time_06.append(tt)
    amp_06.append(aa)
    phase_06.append(pp)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 4))
for i in range(n_file_06):
    ax.plot(time_06[i], amp_06[i]/(-1*0.0125), alpha=0.8)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Charge (-$e$)')
ax.set_ylim(-45, 10)
ax.set_xlim(0, 400)
ax.set_title('ND Filter: OD 0.6')
# Out:
# Text(0.5, 1.0, 'ND Filter: OD 0.6')

# %%
data_dir = r"C:\Users\yuhan\Documents\Data\charging\20240515_uvcharging_dataset\nd_0_3_0_6"
n_file_09 = 6

time_09, amp_09, phase_09 = [], [], []
for i in range(n_file_09):
    prefix = '1100v_7_95Hz_' + str(i)
    file_list = glob.glob(f"{data_dir}\{prefix}\*.mat")
    tt, aa, pp = load_charging_files(file_list)
    
    # plot_charging(tt, aa, pp)
    # plot_charging_calibrated(tt, aa, 0.0125)
    time_09.append(tt)
    amp_09.append(aa)
    phase_09.append(pp)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 4))
for i in range(n_file_09):
    ax.plot(time_09[i], amp_09[i]/(-1*0.0125), alpha=0.8)

ax.set_xlabel('Time (s)')
ax.set_ylabel('Charge (-$e$)')
ax.set_ylim(-45, 10)
ax.set_xlim(0, 2500)
ax.set_title('ND Filter: OD 0.9 (0.3 + 0.6)')
# Out:
# Text(0.5, 1.0, 'ND Filter: OD 0.9 (0.3 + 0.6)')

# %% [markdown]
# #### Plotting them all together

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 4))
for i in range(n_file_0-1):
    if i == 1:
        ax.plot(time[i], amp[i]/(-1*0.0125), alpha=0.8, color='k', label='No Filter')
    else:
        ax.plot(time[i], amp[i]/(-1*0.0125), alpha=0.8, color='k')
for i in range(n_file_03):
    if i == 1:
        ax.plot(time_03[i], amp_03[i]/(-1*0.0125), alpha=0.8, color='r', label='ND 0.3')
    else:
        ax.plot(time_03[i], amp_03[i]/(-1*0.0125), alpha=0.8, color='r')
for i in range(n_file_06):
    if i == 1:
        ax.plot(time_06[i], amp_06[i]/(-1*0.0125), alpha=0.8, color='b', label='ND 0.6')
    else:
        ax.plot(time_06[i], amp_06[i]/(-1*0.0125), alpha=0.8, color='b')
for i in range(n_file_09):
    if i == 1:
        ax.plot(time_09[i], amp_09[i]/(-1*0.0125), alpha=0.8, color='g', label='ND 0.9')
    else:
        ax.plot(time_09[i], amp_09[i]/(-1*0.0125), alpha=0.8, color='g')

ax.legend(frameon=False)
ax.set_xlabel('Time (s)')
ax.set_ylabel('Charge (-$e$)')
ax.set_ylim(-45, 10)
ax.set_xlim(0, 2500)
# Out:
# (0.0, 2500.0)

# %% [markdown]
# #### Calculate emission rate at 0 charge

# %%
rate = np.zeros(len(time))
rate_03 = np.zeros(len(time_03))
rate_06 = np.zeros(len(time_06))
rate_09 = np.zeros(len(time_09))

# %%
power = [1, 0.5, 0.25, 0.13]
r_list = [rate, rate_03, rate_06, rate_09]
t_list = [time, time_03, time_06, time_09]
a_list = [amp, amp_03, amp_06, amp_09]

# %%
for i, rr in enumerate(r_list):
    for j, r in enumerate(rr):
        rr[j] = get_emission_rate(t_list[i][j], a_list[i][j], 0.0125)
# Out:
# C:\Users\yuhan\AppData\Local\Temp\ipykernel_13088\357085634.py:4: RuntimeWarning: invalid value encountered in cast
#   return np.round(savgol_filter(raw_charge, 10, 1)).astype(int)

# %%
stats = np.empty(shape=(len(r_list), 3))
for i, stat in enumerate(stats):
    stats[i] = np.percentile(r_list[i], [5, 50, 95])

# %%
def func(x, a):
    return a*x
    
fig, ax = plt.subplots(1, 1, figsize = (6, 4))
err_plot = [np.log(medians/rmin)-np.log(stats.T[0]/rmin), np.log(stats.T[2]/rmin)-np.log(medians/rmin)]
err_fit = ( np.log(stats.T[2]/rmin) - np.log(stats.T[0]/rmin) ) / 2

popt, pcov = curve_fit(func, np.log(power/pmin), np.log(medians/rmin), sigma=err_fit)
ax.plot(np.log(power/pmin), func(np.log(power/pmin), *popt), 'r--', label=f'y={popt[0]:.2f} x')

ax.errorbar(np.log(power/pmin), np.log(medians/rmin), yerr=err_plot, color='b')

ax.legend(frameon=False, fontsize=10, labelcolor='r', loc='upper left')
ax.set_ylabel(r'log (R/R$_\mathrm{min}$)', fontsize=14)
ax.set_xlabel(r'log (P/P$_\mathrm{min}$)', fontsize=14)
# Out:
# Text(0.5, 0, 'log (P/P$_\\mathrm{min}$)')

# %%
def func1(x, b):
    return 1*x + b
def func2(x, b):
    return 2*x + b
def func3(x, b):
    return 3*x + b

# %%
rmin = np.min(medians)
pmin = np.min(power)
medians = stats.T[1]
errors = (stats.T[1]-stats.T[0], stats.T[2]-stats.T[1])

pp = np.linspace(1, 8, 100)

fig, ax = plt.subplots(1, 1, figsize = (6, 4))
ax.errorbar(power/pmin, medians/rmin, yerr=errors/medians[3], color='b')
ax.plot(pp, np.exp(func1(np.log(pp), 0)), 'g--', label=r'$\propto (\mathrm{P}/\mathrm{P}_\mathrm{min})^1$')
ax.plot(pp, np.exp(func2(np.log(pp), 0)), '--', color='cyan', label=r'$\propto (\mathrm{P}/\mathrm{P}_\mathrm{min})^2$')
ax.plot(pp, np.exp(func3(np.log(pp), 0)), '--', color='darkorange', label=r'$\propto (\mathrm{P}/\mathrm{P}_\mathrm{min})^3$')
ax.plot(pp, np.exp(func(np.log(pp), *popt)), 'r--', label=r'Best fit: $\propto (\mathrm{P}/\mathrm{P}_\mathrm{min})^{2.26}$')

ax.set_ylim(0, 80)
ax.legend(frameon=False, fontsize=12, loc='upper left')
ax.set_ylabel(r'Relative emission rate R/R$_\mathrm{min}$', fontsize=14)
ax.set_xlabel(r'Relative power P/P$_\mathrm{min}$', fontsize=14)
# Out:
# Text(0.5, 0, 'Relative power P/P$_\\mathrm{min}$')
