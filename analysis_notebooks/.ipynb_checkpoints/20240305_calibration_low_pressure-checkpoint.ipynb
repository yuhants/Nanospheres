# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import welch, stft, butter, lfilter, sosfilt
from scipy.optimize import curve_fit

# %%
def get_psd(data, channel=1, time_unit='s'):
    if time_unit == 's':
        tt = data[0]
    elif time_unit == 'ms':
        tt = data[0] / 1000

    fs = int(np.ceil(1 / (tt[1] - tt[0])))
    nperseg = fs / 10
    
    ff, pp = welch(data[channel], fs=fs, nperseg=nperseg)
    return ff, pp

def get_peak_area(data, channel=1, time_unit='s', fdrive=20000):
    """Integrate to get the area under a driven peak"""
    ff, pp = get_psd(data, channel, time_unit)
    
    peak_idx = int(fdrive / 10)
    lb, ub = peak_idx-10, peak_idx+10
    
    all_idx = np.arange(lb, ub, 1)
    excluding_peak = np.logical_or(all_idx < (peak_idx-3), all_idx > (peak_idx+3))

    area_all = np.trapz(pp[all_idx], ff[all_idx]*2*np.pi)
    area_excluding_peak = np.trapz( pp[all_idx[excluding_peak]], ff[all_idx[excluding_peak]]*2*np.pi )

    # Excluding background contribution (which is very small anyway)
    # Take care of 2 pi normalization after numerical integration
    # because we integrated over omega here
    v2_drive = (area_all - area_excluding_peak) / (2 * np.pi)
    
    return v2_drive

def peak_func(x, amp, omega_0, gamma):
    """A Lorentzian line shape"""
    return amp * gamma / ( ( omega_0**2 - x**2)**2 + gamma**2 * x**2 )

def fit_peak(x, y, peak_func, p0=None):
    popt, pcov = curve_fit(peak_func, x, y, p0=p0)
    
    # Return central frequency and gamma
    return popt, x, peak_func(x, *popt)

# %%
def get_filtered_signal(data, f_hp=10000, f_lp=100000, time_unit='ms', channel=1):
    if time_unit == 's':
        tt = data[0]
    elif time_unit == 'ms':
        tt = data[0] / 1000
        
    fs = int(np.ceil(1 / (tt[1] - tt[0]))) # Sampling rate in Hz
    sos_hp = butter(8, f_hp, 'hp', fs=fs, output='sos')
    sos_lp = butter(8, f_lp, 'lp', fs=fs, output='sos')
    filtered = sosfilt(sos_hp, data[channel])
    filtered_filtered = sosfilt(sos_lp, filtered)
    
    return filtered_filtered

def lowpass_filtered(tod, fs, f_lp=50000):
    sos_lp = butter(8, f_lp, 'lp', fs=fs, output='sos')
    filtered = sosfilt(sos_lp, tod)
    
    return filtered

def highpass_filtered(tod, fs, f_hp=50000):
    sos_hp = butter(8, f_hp, 'hp', fs=fs, output='sos')
    filtered = sosfilt(sos_hp, tod)
    
    return filtered

# %%
data_file = r"C:\Users\yuhan\Documents\Data\calibration\20240304_noefield_1e-7mbar_xyz.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

ffy, ppy = get_psd(data, 1, 's')
ffx, ppx = get_psd(data, 2, 's')
ffz, ppz = get_psd(data, 3, 's')
# fff, ppf = get_psd(data, 4, 's')

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.plot(ffx/1000, ppx, label='X detection')
ax.plot(ffy/1000, ppy, label='Y detection')
ax.plot(ffz/1000, ppz, label='Z detection', alpha=0.7)
# ax.plot(fff/1000, ppf, label='Feedback', alpha=0.7)
ax.set_xlim(0, 600)

ax.set_title(r'Low Pressure ($1 \times 10^{-7}$ mbar)')
ax.set_xlabel('Frequency $\omega / 2 \pi$ (kHz)', fontsize=14)
ax.set_ylabel('Spectral density (V$^2$/Hz)', fontsize=14)

ax.legend(frameon=False, fontsize=14)
ax.set_yscale('log')

# %%
lb, ub = 5000, 6000
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(ffz[lb:ub]/1000, ppz[lb:ub], 'b', label='Z detection')
ax.set_yscale('log')

# Fit with a Lorentzian and plot
lb_fit, ub_fit = 5470, 5495
popt, omega_fit, p_fit = fit_peak(ffz[lb_fit:ub_fit]*2*np.pi, ppz[lb_fit:ub_fit], peak_func, p0=[500000, 54500*2*np.pi, 500])
amp_low, omega0_low, gamma_low = popt[0], popt[1], popt[2]
print(f'Low Pressure - Amplitude: {amp_low}, central frequency: {omega0_low/(2*np.pi)} Hz, gamma: {gamma_low/(2*np.pi)} Hz')

ax.plot(omega_fit/(2*np.pi)/1000, p_fit, 'r', alpha=0.7)
# Out:
# Low Pressure - Amplitude: 124954.48423815645, central frequency: 54805.0945937634 Hz, gamma: 91.75514312401879 Hz

# %% [markdown]
# Split the 10 s data into 500 ms chunks and see how much the peak is drifting (it looks stable over 10 s)

# %%
tt_chunks = np.array_split(data[0], 20)
zz_chunks = np.array_split(data[3], 20)

ffz_chunks, ppz_chunks = [], []
for i, zz in enumerate(zz_chunks):
    tt = tt_chunks[i]

    fs = int(np.ceil(1 / (tt[1] - tt[0])))
    nperseg = fs / 10
    
    ffz, ppz = welch(zz, fs=fs, nperseg=nperseg)
    ffz_chunks.append(ffz)
    ppz_chunks.append(ppz)

# %%
lb, ub = 5000, 6000
fig, ax = plt.subplots(figsize=(6,4))

for i, pp in enumerate(ppz_chunks):
    ffz = ffz_chunks[i]
    
    ax.plot(ffz[lb:ub]/1000, ppz[lb:ub], label='Z detection', alpha=0.5)
    ax.set_yscale('log')

# %%
data_file = r"C:\Users\yuhan\Documents\Data\calibration\20240304_nohv_60khz_1vp2p_1e-7mbar.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

ff, pp = get_psd(data, channel=1, time_unit='s')

# %%
lb, ub = 4000, 7000
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(ff[lb:ub], pp[lb:ub], 'b', label='Z detection')

ax.set_title(r'Low Pressure ($1 \times 10^{-7}$ mbar)')
ax.set_xlabel('Frequency $\omega / 2 \pi$ (Hz)', fontsize=14)
ax.set_ylabel('Spectral density ($V^2$/Hz)', fontsize=14)

# ax.set_ylim(1e-10)
ax.set_yscale('log')

# %%
drive_amp = 1 # V; peak to peak
f_drive = 60000
omega_drive = f_drive * 2 * np.pi

# Electric force on the particle
charge = 3 * 1.6e-19
efield = 120          # V/m when 1 V is applied
amp = drive_amp / 2   # Because what's in the file is the peak-to-peak amplitude and we want the amp from zero
f0 = charge * amp * efield

# Particle mass
rho = 2000 # kg/m^3
r   = 167e-9 / 2
m   = rho * (4 * np.pi / 3) * r**3 

x2 = (f0**2 / (2 * m**2) ) / ((omega0_low**2 - omega_drive**2)**2 + gamma_low**2 * omega_drive**2)

v2_drive = get_peak_area(data, 1, 's', f_drive)
c_cal_square = v2_drive / x2

print(f'Calibration factor square is {c_cal_square}.')
# Out:
# Calibration factor square is 2331185280123.3506.

# %%
lb, ub = 4000, 7000
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(ff[lb:ub]/1000, pp[lb:ub]/c_cal_square, 'b', label='Z detection')

ax.set_title(r'Low Pressure ($1 \times 10^{-7}$ mbar)')
ax.set_xlabel('Frequency $\omega / 2 \pi$ (kHz)', fontsize=14)
ax.set_ylabel('Spectral density (m$^2$/Hz)', fontsize=14)

ax.legend(frameon=False, fontsize=14)
ax.set_yscale('log')

# %% [markdown]
# ## Measuring the transfer function

# %%
data_file_1 = r"C:\Users\yuhan\Documents\Data\calibration\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar_1.csv"
data_file_2 = r"C:\Users\yuhan\Documents\Data\calibration\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar_2.csv"
data_file_3 = r"C:\Users\yuhan\Documents\Data\calibration\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar_3.csv"
data_file_4 = r"C:\Users\yuhan\Documents\Data\calibration\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar\20240304_freqcomb_2070_2khz_025vp2p_1e-7mbar_4.csv"

data_1 = np.genfromtxt(data_file_1, delimiter=',', skip_header=3).T
data_2 = np.genfromtxt(data_file_2, delimiter=',', skip_header=3).T
data_3 = np.genfromtxt(data_file_3, delimiter=',', skip_header=3).T
data_4 = np.genfromtxt(data_file_4, delimiter=',', skip_header=3).T

# %%
ff, pp = get_psd(data_1)

lb, ub = 1900, 7100
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(ff[lb:ub], pp[lb:ub])

ax.set_title('Drive = 20 to 70 kHz @ 0.5 V P2P each')
ax.set_xlabel('Frequency (Hz)')
ax.set_ylabel('Spectral density ($V^2 / Hz$)')

ax.set_yscale('log')

# %%
freq_comb_file = r"C:\Users\yuhan\nanospheres\Experiment Control\freq_comb_20khz_70khz_deltaf2khz.npz"

comb_data = np.load(freq_comb_file, allow_pickle=True)
ff_drive = comb_data['ff']

# %%
def get_transfer_func(charge_e, drive_amp, ff_drive, data):
    charge0 = charge_e * 1.6e-19
    efield = 120          # V/m when 1 V is applied
    amp = drive_amp / 2   # Because what's in the file is the peak-to-peak amplitude and we want the amp from zero

    chisquare = np.zeros_like(ff_drive, dtype=np.float64)
    f0 = charge0 * amp * efield
    
    for i, f in enumerate(ff_drive):
        v2_drive = get_peak_area(data_2, 1, 's', f)
        x2_drive = v2_drive / c_cal_square
        
        chisquare_drive = 2 * x2_drive / (f0**2)
        
        chisquare[i] = chisquare_drive

# %%
charge0 = 3 * 1.6e-19
drive_amp = 0.5  # peak-to-peak voltage for each freq component in V

efield = 120          # V/m when 1 V is applied
amp = drive_amp / 2   # Because what's in the file is the peak-to-peak amplitude and we want the amp from zero

chisquare = np.zeros_like(ff_drive, dtype=np.float64)

f0 = charge0 * amp * efield

for i, f in enumerate(ff_drive):
    v2_drive = get_peak_area(data_2, 1, 's', f)
    x2_drive = v2_drive / c_cal_square
    
    chisquare_drive = 2 * x2_drive / (f0**2)
    
    chisquare[i] = chisquare_drive

# %%
lb, ub = 2000, 7000

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(ff_drive/1000, chisquare, 'o', label='Measured assuming 3e')

ax.plot(ff[lb:ub]/1000, peak_func(ff[lb:ub]*2*np.pi, 1/(m * m * gamma_low), omega0_low, gamma_low), label='Theory from displacement noise fit')

ax.set_title(r'Pressure $\approx$ 1e-7 mbar')
ax.set_xlabel(r'Frequency $\omega / 2 \pi$ (kHz)', fontsize=14)
ax.set_ylabel(r'Susceptibility $| \chi[\omega] |^2$', fontsize=14)
ax.legend(loc='lower left', frameon=False, fontsize=12)
ax.tick_params(axis='both', which='both', direction='in', labelsize=14)
ax.set_yscale('log')

# %% [markdown]
# ## Apply electric kicks

# %% [markdown]
# #### 21.5 MeV pulses

# %%
file_kick_1 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz\20240304_25v_8us_1e-7mbar_xyz_1.csv"
file_kick_2 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz\20240304_25v_8us_1e-7mbar_xyz_2.csv"
file_kick_3 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz\20240304_25v_8us_1e-7mbar_xyz_3.csv"
file_kick_4 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz\20240304_25v_8us_1e-7mbar_xyz_4.csv"

data_kick_1 = np.genfromtxt(file_kick_1, delimiter=',', skip_header=3).T
data_kick_2 = np.genfromtxt(file_kick_2, delimiter=',', skip_header=3).T
data_kick_3 = np.genfromtxt(file_kick_3, delimiter=',', skip_header=3).T
data_kick_4 = np.genfromtxt(file_kick_4, delimiter=',', skip_header=3).T

# %%
data_kick = [data_kick_1, data_kick_2, data_kick_3, data_kick_4]

fig, ax = plt.subplots(4, 1, figsize = (16, 10))

for i, d in enumerate(data_kick):    
    filtered = get_filtered_signal(d, 53000, 60000, 's', channel=3)
    
    z_mv = filtered*1000
    fs = int(np.ceil(1 / (d[0, 1] - d[0, 0]))) 

    lp_filtered = lowpass_filtered(z_mv, fs, 20)

    a = ax[i]
    a.plot(d[0][0:1000000], z_mv[0:1000000], label="Z detection (filtered)", color='lightseagreen', linewidth=2)
    a2 = a.twinx()

    a2.plot(d[0][0:1000000], d[4][0:1000000], 'darkblue', alpha=0.6)

    a2.set_ylabel('Signal (V)', fontsize=14, color='darkblue')
    a.set_ylabel('Filtered z signal (mV)', fontsize=14)

    a2.tick_params(axis='both', which='both', direction='in', labelsize=14, color='darkblue')
    # ax2.set_ylim(0, 21)

for a in ax.flatten():
    a.set_ylim(-10, 10)
    a.tick_params(axis='both', which='both', direction='in', labelsize=14)
    
ax[3].set_xlabel('Time (s)', fontsize=14)
plt.suptitle('21.5 MeV Pulses', fontsize=16)
# Out:
# Text(0.5, 0.98, '21.5 MeV Pulses')

# %%
file_kick_1 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz_zhgain\20240304_25v_8us_1e-7mbar_xyz_zhgain_1.csv"
file_kick_2 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz_zhgain\20240304_25v_8us_1e-7mbar_xyz_zhgain_2.csv"
file_kick_3 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz_zhgain\20240304_25v_8us_1e-7mbar_xyz_zhgain_3.csv"
file_kick_4 = r"C:\Users\yuhan\Documents\Data\pulse\20240304_25v_8us_1e-7mbar_xyz_zhgain\20240304_25v_8us_1e-7mbar_xyz_zhgain_4.csv"

data_kick_1 = np.genfromtxt(file_kick_1, delimiter=',', skip_header=3).T
data_kick_2 = np.genfromtxt(file_kick_2, delimiter=',', skip_header=3).T
data_kick_3 = np.genfromtxt(file_kick_3, delimiter=',', skip_header=3).T
data_kick_4 = np.genfromtxt(file_kick_4, delimiter=',', skip_header=3).T

# %%
data_kick = [data_kick_1, data_kick_2, data_kick_3, data_kick_4]

fig, ax = plt.subplots(4, 1, figsize = (16, 10))

for i, d in enumerate(data_kick):    
    filtered = get_filtered_signal(d, 53000, 60000, 's', channel=3)
    
    z_mv = filtered*1000
    fs = int(np.ceil(1 / (d[0, 1] - d[0, 0]))) 

    lp_filtered = lowpass_filtered(z_mv, fs, 20)

    a = ax[i]
    a.plot(d[0][0:1000000], z_mv[0:1000000], label="Z detection (filtered)", color='lightseagreen', linewidth=2)
    a2 = a.twinx()

    a2.plot(d[0][0:1000000], d[4][0:1000000], 'darkblue', alpha=0.6)

    a2.set_ylabel('Signal (V)', fontsize=14, color='darkblue')
    a.set_ylabel('Filtered z signal (mV)', fontsize=14)

    a2.tick_params(axis='both', which='both', direction='in', labelsize=14, color='darkblue')
    # ax2.set_ylim(0, 21)

for a in ax.flatten():
    a.set_ylim(-10, 10)
    a.tick_params(axis='both', which='both', direction='in', labelsize=14)
    
ax[3].set_xlabel('Time (s)', fontsize=14)
plt.suptitle('21.5 MeV Pulses', fontsize=16)
# Out:
# Text(0.5, 0.98, '21.5 MeV Pulses')
