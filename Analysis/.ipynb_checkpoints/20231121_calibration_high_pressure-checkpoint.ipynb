# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.signal import butter, sosfilt, stft, welch
from scipy.optimize import curve_fit

# %%
def get_psd(data, channel=1):
    fs = int(np.ceil(1 / (data[0, 1] - data[0, 0])))
    nperseg = fs / 10
    
    ff, pp = welch(data[channel], fs=fs, nperseg=nperseg)
    return ff, pp

def peak_amplitude_stft(tod, fs, nperseg, driving_freq):
    
    ff, tt, Zxx = stft(tod, fs=fs, nperseg=nperseg)
    sig = np.abs(Zxx)
    # f = np.where(ff==driving_freq)[0][0]
    f = np.argmin(np.abs(ff - driving_freq))

    # time, peak amplitude^2, sample frequency, sftp
    return tt, sig[f], ff, Zxx[f]

# %%
def get_filtered_signal(data, f_hp, f_lp, order=8):
    fs = int(np.ceil(1 / (data[0, 1] - data[0, 0]))) * 1000 # Sampling rate in Hz
    
    sos_hp = butter(order, f_hp, 'hp', fs=fs, output='sos')
    sos_lp = butter(order, f_lp, 'lp', fs=fs, output='sos')
    
    filtered = sosfilt(sos_hp, data[1])
    filtered_filtered = sosfilt(sos_lp, filtered)
    
    return filtered_filtered

# %%
def plot_peak_amp(data, drive_freq, filtered=True):
    fs = int(np.ceil(1 / (data[0, 1] - data[0, 0])))
#     nperseg = fs / 5
    nperseg = fs / 5
    
    if filtered:
        f_hp = 1000
        sos_hp = butter(4, f_hp, 'hp', fs=fs, output='sos')
        dd = sosfilt(sos_hp, data[1])
    else:
        dd = data[1]

    tt, sig, ff, Zxx = peak_amplitude_stft(dd, fs, nperseg, drive_freq)
    
    fig, ax = plt.subplots(figsize = (20, 6))
    ax.grid()
    ax.plot(tt, sig, 'r.', markersize=15)

    ax.set_xlabel('Time (s)', fontsize=18)
    ax.set_ylabel(f'Peak amplitude@{int(drive_freq/1000)} kHz (V)', fontsize=18)
    ax.set_title('0.1 mbar, driving field = 20 V peak to peak', fontsize=20)
    
    return fig, ax

# %%
def plot_peak_area(data, drive_freq):
    fs = int(np.ceil(1 / (data[0, 1] - data[0, 0])))
    nperseg = fs / 5
    
    tod = data[1]
    ff, tt, Zxx = stft(tod, fs=fs, nperseg=nperseg)
    squared = np.abs(Zxx)**2
    
    idx_drive = np.argmin(np.abs(ff - drive_freq))
    lb, ub = idx_drive-3, idx_drive+3
    
    print(ff.shape)
    print(squared.shape)
    
    area_peak = np.zeros(squared.shape[1])
    for i, a in enumerate(area_peak):
        area_peak[i] = np.trapz(squared.T[i][lb:ub], ff[lb:ub]*2*np.pi)
    
    fig, ax = plt.subplots(figsize = (20, 6))
    ax.grid()
    ax.plot(tt, area_peak, '-')

    ax.set_xlabel('Time (s)', fontsize=18)
    ax.set_ylabel(f'Peak area@{int(drive_freq/1000)} kHz (V)', fontsize=18)
    ax.set_title('0.1 mbar, driving field = 20 V peak to peak', fontsize=20)
    
    return fig, ax

# %% [markdown]
# ## Determine the charge state of the nanosphere

# %%
data_file = r"D:\Experiment\Charging\20231116\charging_44khz_50s_2.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

# %%
fig, ax = plot_peak_amp(data, 44000, False)

# %%
fig, ax = plot_peak_area(data, 44000)
# Out:
# (20001,)
# (20001, 502)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_5.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_6.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_7.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_8.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_9.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_10.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_11.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_12.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_13.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_14.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_15.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_16.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_17.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_18.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_19.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_44khz_dcbias_50s_20.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\nohv_44khz_dcbias_50s_20.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %% [markdown]
# Looks like there are 2 charges on the sphere.
# The sphere was difficult to cool and fell out while pumping down.

# %% [markdown]
# ## Sphere number 2

# %%
data_file = r"D:\Experiment\Charging\20231117\nohv_p2_44khz_50s_0.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_0.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_20s_1.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_2.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_3.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_20s_4.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_20s_5.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_6.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_7.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_8.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_9.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\charging_p2_44khz_50s_10.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)

# %%
data_file = r"D:\Experiment\Charging\20231117\nohv_p2_44khz_20s_10.csv"
data = np.genfromtxt(data_file, delimiter=',', skip_header=3).T

fig, ax = plot_peak_amp(data, 44000, False)
